# %%
# !pip install -q wordcloud
import wordcloud

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
import nltk
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import io
import unicodedata
import numpy as np
import re
import string

# %%
import pandas as pd
import re
import nltk
import spacy
import string
pd.options.mode.chained_assignment = None

full_df = pd.read_csv("/content/Restaurant reviews.csv", nrows=1000)

full_df.head(20)
# Out:
#          Restaurant              Reviewer  \
# 0   Beyond Flavours     Rusha Chakraborty
# 1   Beyond Flavours  Anusha Tirumalaneedi
# 2   Beyond Flavours       Ashok Shekhawat
# 3   Beyond Flavours        Swapnil Sarkar
# 4   Beyond Flavours                Dileep
# 5   Beyond Flavours         Nagabhavani K
# 6   Beyond Flavours       Jamuna Bhuwalka
# 7   Beyond Flavours             Sandhya S
# 8   Beyond Flavours          Akash Thorat
# 9   Beyond Flavours        Smarak Patnaik
# 10  Beyond Flavours      Saubhagya Bhuyan
# 11  Beyond Flavours            Srivaths07
# 12  Beyond Flavours           Kunj Mishra
# 13  Beyond Flavours     Pradeep Vetapalem
# 14  Beyond Flavours         Kankaria.ritu
# 15  Beyond Flavours          Abhay Sharma
# 16  Beyond Flavours       Shubham Jaiswal
# 17  Beyond Flavours     Srijani Mukherjee
# 18  Beyond Flavours           Hari Jangam
# 19  Beyond Flavours           Suneet Soni
#
#                                                Review  Rating  \
# ...

# %%
df=full_df[['Reviewer','Review','Rating','Metadata'	]]
df.head()
# Out:
#                Reviewer                                             Review  \
# 0     Rusha Chakraborty  The ambience was good, food was quite good . h...
# 1  Anusha Tirumalaneedi  Ambience is too good for a pleasant evening. S...
# 2       Ashok Shekhawat  A must try.. great food great ambience. Thnx f...
# 3        Swapnil Sarkar  Soumen das and Arun was a great guy. Only beca...
# 4                Dileep  Food is good.we ordered Kodi drumsticks and ba...
#
#    Rating                 Metadata
# 0     5.0   1 Review , 2 Followers
# 1     5.0  3 Reviews , 2 Followers
# 2     5.0  2 Reviews , 3 Followers
# 3     5.0    1 Review , 1 Follower
# 4     5.0  3 Reviews , 2 Followers

# %%
df.isna().sum()
# Out:
# Reviewer    0
# Review      0
# Rating      0
# Metadata    0
# dtype: int64

# %%
df = full_df[["Review"]]
df["Review"] = df["Review"].astype(str)
df.head()
# Out:
#                                               Review
# 0  The ambience was good, food was quite good . h...
# 1  Ambience is too good for a pleasant evening. S...
# 2  A must try.. great food great ambience. Thnx f...
# 3  Soumen das and Arun was a great guy. Only beca...
# 4  Food is good.we ordered Kodi drumsticks and ba...

# %%
df["Review_lower"] = df["Review"].str.lower()
df.head()
# Out:
#                                               Review  \
# 0  The ambience was good, food was quite good . h...
# 1  Ambience is too good for a pleasant evening. S...
# 2  A must try.. great food great ambience. Thnx f...
# 3  Soumen das and Arun was a great guy. Only beca...
# 4  Food is good.we ordered Kodi drumsticks and ba...
#
#                                         Review_lower
# 0  the ambience was good, food was quite good . h...
# 1  ambience is too good for a pleasant evening. s...
# 2  a must try.. great food great ambience. thnx f...
# 3  soumen das and arun was a great guy. only beca...
# 4  food is good.we ordered kodi drumsticks and ba...

# %%
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

df["Review_lo_punct"] = df["Review_lower"].apply(lambda text: remove_punctuation(text))
df.head()
# Out:
#                                               Review  \
# 0  The ambience was good, food was quite good . h...
# 1  Ambience is too good for a pleasant evening. S...
# 2  A must try.. great food great ambience. Thnx f...
# 3  Soumen das and Arun was a great guy. Only beca...
# 4  Food is good.we ordered Kodi drumsticks and ba...
#
#                                         Review_lower  \
# 0  the ambience was good, food was quite good . h...
# 1  ambience is too good for a pleasant evening. s...
# 2  a must try.. great food great ambience. thnx f...
# 3  soumen das and arun was a great guy. only beca...
# 4  food is good.we ordered kodi drumsticks and ba...
#
#                                      Review_lo_punct
# 0  the ambience was good food was quite good  had...
# 1  ambience is too good for a pleasant evening se...
# 2  a must try great food great ambience thnx for ...
# 3  soumen das and arun was a great guy only becau...
# 4  food is goodwe ordered kodi drumsticks and bas...

# %%
df.drop(["Review_lower"], axis=1, inplace=True)
df
# Out:
#                                                 Review  \
# 0    The ambience was good, food was quite good . h...
# 1    Ambience is too good for a pleasant evening. S...
# 2    A must try.. great food great ambience. Thnx f...
# 3    Soumen das and Arun was a great guy. Only beca...
# 4    Food is good.we ordered Kodi drumsticks and ba...
# ..                                                 ...
# 995                                           not ggod
# 996  They didn't packed the ice cream nicely ie.. d...
# 997  ice cream was melted before it reached me and ...
# 998  Ice cream was good , but it's totally got melt...
# 999  1.Half of ice cream spilled inside the package...
#
#                                        Review_lo_punct
# 0    the ambience was good food was quite good  had...
# 1    ambience is too good for a pleasant evening se...
# 2    a must try great food great ambience thnx for ...
# 3    soumen das and arun was a great guy only becau...
# ...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words('english'))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, m
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

df["Review_wo_stop"] = df["Review_lo_punct"].apply(lambda text: remove_stopwords(text))
df.head()
# Out:
#                                               Review  \
# 0  The ambience was good, food was quite good . h...
# 1  Ambience is too good for a pleasant evening. S...
# 2  A must try.. great food great ambience. Thnx f...
# 3  Soumen das and Arun was a great guy. Only beca...
# 4  Food is good.we ordered Kodi drumsticks and ba...
#
#                                      Review_lo_punct  \
# 0  the ambience was good food was quite good  had...
# 1  ambience is too good for a pleasant evening se...
# 2  a must try great food great ambience thnx for ...
# 3  soumen das and arun was a great guy only becau...
# 4  food is goodwe ordered kodi drumsticks and bas...
#
#                                       Review_wo_stop
# 0  ambience good food quite good saturday lunch c...
# 1  ambience good pleasant evening service prompt ...
# 2  must try great food great ambience thnx servic...
# 3  soumen das arun great guy behavior sincerety g...
# 4  food goodwe ordered kodi drumsticks basket mut...

# %%
from collections import Counter
cnt = Counter()
for text in df["Review_wo_stop"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(10)
# Out:
# [('good', 794),
#  ('food', 724),
#  ('place', 562),
#  ('service', 393),
#  ('chicken', 287),
#  ('great', 254),
#  ('ambience', 240),
#  ('one', 217),
#  ('taste', 212),
#  ('ordered', 207)]

# %%
FREQWORDS = set([w for (w, wc) in cnt.most_common(10)])
def remove_freqwords(text):
    """custom function to remove the frequent words"""
    return " ".join([word for word in str(text).split() if word not in FREQWORDS])

df["Review_wo_stopfreq"] = df["Review_wo_stop"].apply(lambda text: remove_freqwords(text))
df.head()
# Out:
#                                               Review  \
# 0  The ambience was good, food was quite good . h...
# 1  Ambience is too good for a pleasant evening. S...
# 2  A must try.. great food great ambience. Thnx f...
# 3  Soumen das and Arun was a great guy. Only beca...
# 4  Food is good.we ordered Kodi drumsticks and ba...
#
#                                      Review_lo_punct  \
# 0  the ambience was good food was quite good  had...
# 1  ambience is too good for a pleasant evening se...
# 2  a must try great food great ambience thnx for ...
# 3  soumen das and arun was a great guy only becau...
# 4  food is goodwe ordered kodi drumsticks and bas...
#
#                                       Review_wo_stop  \
# 0  ambience good food quite good saturday lunch c...
# 1  ambience good pleasant evening service prompt ...
# 2  must try great food great ambience thnx servic...
# 3  soumen das arun great guy behavior sincerety g...
# ...

# %%
n_rare_words = 10
RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-n_rare_words-1:-1]])
def remove_rarewords(text):
    """custom function to remove the rare words"""
    return " ".join([word for word in str(text).split() if word not in RAREWORDS])

df["Review_wo_stopfreqrare"] = df["Review_wo_stopfreq"].apply(lambda text: remove_rarewords(text))
df.head()
# Out:
#                                               Review  \
# 0  The ambience was good, food was quite good . h...
# 1  Ambience is too good for a pleasant evening. S...
# 2  A must try.. great food great ambience. Thnx f...
# 3  Soumen das and Arun was a great guy. Only beca...
# 4  Food is good.we ordered Kodi drumsticks and ba...
#
#                                      Review_lo_punct  \
# 0  the ambience was good food was quite good  had...
# 1  ambience is too good for a pleasant evening se...
# 2  a must try great food great ambience thnx for ...
# 3  soumen das and arun was a great guy only becau...
# 4  food is goodwe ordered kodi drumsticks and bas...
#
#                                       Review_wo_stop  \
# 0  ambience good food quite good saturday lunch c...
# 1  ambience good pleasant evening service prompt ...
# 2  must try great food great ambience thnx servic...
# 3  soumen das arun great guy behavior sincerety g...
# ...

# %%
df.drop(["Review_lo_punct", "Review_wo_stop"], axis=1, inplace=True)
df
# Out:
#                                                 Review  \
# 0    The ambience was good, food was quite good . h...
# 1    Ambience is too good for a pleasant evening. S...
# 2    A must try.. great food great ambience. Thnx f...
# 3    Soumen das and Arun was a great guy. Only beca...
# 4    Food is good.we ordered Kodi drumsticks and ba...
# ..                                                 ...
# 995                                           not ggod
# 996  They didn't packed the ice cream nicely ie.. d...
# 997  ice cream was melted before it reached me and ...
# 998  Ice cream was good , but it's totally got melt...
# 999  1.Half of ice cream spilled inside the package...
#
#                                     Review_wo_stopfreq  \
# 0    quite saturday lunch cost effective sate brunc...
# 1    pleasant evening prompt experience soumen das ...
# 2    must try thnx pradeep subroto personal recomme...
# 3    soumen das arun guy behavior sincerety course ...
# ...

# %% [markdown]
# #**stemming**

# %%
from nltk.stem.porter import PorterStemmer

# Drop the two columns 
df.drop(["Review_wo_stopfreq", "Review_wo_stopfreqrare"], axis=1, inplace=True) 

stemmer = PorterStemmer()
def stem_words(text):
    return " ".join([stemmer.stem(word) for word in text.split()])

df["Review_stemmed"] = df["Review"].apply(lambda text: stem_words(text))
df.head()
# Out:
#                                               Review  \
# 0  The ambience was good, food was quite good . h...
# 1  Ambience is too good for a pleasant evening. S...
# 2  A must try.. great food great ambience. Thnx f...
# 3  Soumen das and Arun was a great guy. Only beca...
# 4  Food is good.we ordered Kodi drumsticks and ba...
#
#                                       Review_stemmed
# 0  the ambienc wa good, food wa quit good . had s...
# 1  ambienc is too good for a pleasant evening. se...
# 2  a must try.. great food great ambience. thnx f...
# 3  soumen da and arun wa a great guy. onli becaus...
# 4  food is good.w order kodi drumstick and basket...

# %% [markdown]
# #Lemmatization

# %%
from nltk.stem.snowball import SnowballStemmer
SnowballStemmer.languages
# Out:
# ('arabic',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'hungarian',
#  'italian',
#  'norwegian',
#  'porter',
#  'portuguese',
#  'romanian',
#  'russian',
#  'spanish',
#  'swedish')

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
 import nltk
 nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
# True

# %% [markdown]
# # New Section

# %%
lemmatizer = WordNetLemmatizer()

# %%
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

df["Review_lemmatized"] = df["Review"].apply(lambda text: lemmatize_words(text))
df.head(20)

# %%
lemmatizer.lemmatize("reading")
# Out:
# 'reading'

# %%
lemmatizer.lemmatize("reading", "v")
# Out:
# 'read'

# %%
print("Word is : stripes")
print("Lemma result for verb : ",lemmatizer.lemmatize("stripes", 'v'))
print("Lemma result for noun : ",lemmatizer.lemmatize("stripes", 'n'))
# Out:
# Word is : stripes
# Lemma result for verb :  strip
# Lemma result for noun :  stripe

# %%
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])

df["Review_lemmatized"] = df["Review"].apply(lambda text: lemmatize_words(text))
df.head()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
#                                               Review  \
# 0  The ambience was good, food was quite good . h...
# 1  Ambience is too good for a pleasant evening. S...
# 2  A must try.. great food great ambience. Thnx f...
# 3  Soumen das and Arun was a great guy. Only beca...
# 4  Food is good.we ordered Kodi drumsticks and ba...
#
#                                       Review_stemmed  \
# 0  the ambienc wa good, food wa quit good . had s...
# 1  ambienc is too good for a pleasant evening. se...
# 2  a must try.. great food great ambience. thnx f...
# 3  soumen da and arun wa a great guy. onli becaus...
# 4  food is good.w order kodi drumstick and basket...
#
#                                    Review_lemmatized
# 0  The ambience be good, food be quite good . hav...
# ...
